# %%
import math
import numpy
from matplotlib import pyplot
import aero_functions as aero

# %%
N = 50
x_start, x_end = -2.0, 2.0
y_start, y_end = -1.0, 1.0
X, Y = aero.create_grid(N, x_start, x_end, y_start, y_end)
kappa = 1.0
gamma = 4.0
x_doublet, y_doublet = 0.0, 0.0
u_inf = 1.0

# %%
# doublet velocities
u_doublet, v_doublet, psi_doublet = aero.get_doublet_info(kappa, x_doublet, y_doublet, X, Y)

# freestream
u_fs, v_fs, psi_fs = aero.get_freestream_info(u_inf, 0.0, X, Y, N)

# vortex
u_vortex, v_vortex, psi_vortex = aero.get_vortex_info(gamma, 0.0, 0.0, X, Y)

# combine
u = u_fs + u_doublet + u_vortex
v = v_fs + v_doublet + v_vortex
psi = psi_fs + psi_doublet + psi_vortex

# %%
# %matplotlib inline

# plots the streamlines
size = 10
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.xlim(x_start, x_end)
pyplot.ylim(y_start, y_end)
pyplot.streamplot(X, Y, u, v, density=2, linewidth=1, arrowsize=1, arrowstyle='->')
pyplot.scatter(x_doublet, y_doublet, color='#CD2305', s=80, marker='o')

# calculates the cylinder radius and adds it to the figure
R = numpy.sqrt(kappa/(2*math.pi*u_inf))
circle = pyplot.Circle((0, 0), radius=R, color='#CD2305', alpha=0.5)
pyplot.gca().add_patch(circle)

# calculates the stagnation points and adds it to the figure
x_stagn1, y_stagn1 = +math.sqrt(R**2-(gamma/(4*math.pi*u_inf))**2), -gamma/(4*math.pi*u_inf)
x_stagn2, y_stagn2 = -math.sqrt(R**2-(gamma/(4*math.pi*u_inf))**2), -gamma/(4*math.pi*u_inf)

#x_stags = numpy.sqrt((gamma*(2*numpy.pi*u_inf/kappa+gamma)**(-3.)+(1+2*numpy.pi*u_inf/kappa)*\
#                          (2*numpy.pi*u_inf/kappa+gamma)**(-2.))/\
#                         (1-gamma*(2*numpy.pi*u_inf/kappa+gamma)**(-1.)))
#y_stags = (2*numpy.pi*u_inf/kappa + gamma)**(-1.)

#thetax_stags = numpy.arccos(x_stags/R) * 180 / numpy.pi
#thetay_stags = numpy.arcsin(y_stags/R) * 180 / numpy.pi
#theta_stags = thetax_stags + thetay_stags
#print(theta_stags)

pyplot.scatter([x_stagn1, x_stagn2], [y_stagn1, y_stagn2], color='g', s=80, marker='o');

# %%
help(aero.get_freestream_info)
# Out:
# Help on function get_freestream_info in module aero_functions:
#
# get_freestream_info(u_inf, alpha, Y, N)
#     Returns the cartesian velocities and stream-function
#     generated by a freestream.
#
#     Arguments
#     ---------
#     u_inf -- float; freestream velocity.
#     alpha -- float; freestream angle of attack.
#     Y -- 2D matrix; mesh grid of y values.
#     N -- int; number of discrete points in each direction on our grid.
#
#     Output
#     ---------
#     u, v -- 2D matrix; cartesian velocities of the vortex.
#     psi -- 2D matrix; stream-function on a grid.
